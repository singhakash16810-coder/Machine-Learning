# %% [markdown]
# <a href="https://colab.research.google.com/github/singhakash16810-coder/Machine-Learning/blob/main/python4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RECAP

# %%
type(10)
# Out:
# int

# %%
type("a")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# #DECISON MAKING

# %%
age = 19
if age >= 19:
  print("eligible to vote")
# Out:
# eligible to vote

# %%
passward = str(input())
if passward == "hello@123":
  print("correct passward")
else: print("wrong passward")
# Out:
# hello
# wrong passward

# %%
if 2<3:
  print("A")
else:
   print("B")

print("C")
# Out:
# A
# C

# %%
if 2 < 3:
  print("A")
elif 5>4:
  print("B")
else:
  print("C")
# Out:
# A

# %% [markdown]
# #elif

# %%
marks = 30
if marks<30:
  print("A")
elif ( marks>30)& (marks<70):
  print("B")
else:
  print("C")
# Out:
# C

# %% [markdown]
# <a href="https://colab.research.google.com/github/singhakash16810-coder/Machine-Learning/blob/main/python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables

# %%
name = "AJ"
city = "Nagpur"
id = 24

# %%
print(id)
# Out:
# 24

# %% [markdown]
# #variable using rules
#
# 1. start : alphabet
# 2. middle or end --> alphabet, '_', digits

# %% [markdown]
# variable name = value
#
# name = "akash"

# %%
college = "iit"
print(college)
college = "gl"
print(college)
# Out:
# iit
# gl

# %% [markdown]
# #input from user

# %%
# b = input()
# 5

# %%
# print(a+b)

# %%
"4" + "5"
# Out:
# '45'

# %%
"a"+"b"
# Out:
# 'ab'

# %% [markdown]
# input() -> it is always  as a string

# %% [markdown]
# #Type Csating

# %%
age = "20"
new_age = int(age) # typecasting
type(new_age)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
a = input()
4
b = input()
5
c = int(a) + int(b)
print(c)

# %%
a = int(input())
b = int(input())
c = a+b
print(c)

# %%
birth_year = int(input())
age = 2026-birth_year
print(age)

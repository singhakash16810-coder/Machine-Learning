# %% [markdown]
# <a href="https://colab.research.google.com/github/singhakash16810-coder/Machine-Learning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Recap

# %%
if 4<2:
  print("A")

# %%
if 4<2:
  print("A")
else:
  print("B")
# Out:
# B

# %% [markdown]
# #PRACTISE

# %%
age = 19;
if age>18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
num = 24;
if num%2==0:
  print("even number")
else:
  print("odd number")
# Out:
# even number

# %%
a = int(input())
b = int(input())

if a>b:
  print("larger number ",a)
elif a<b:
  print("larger number is ",b)
else:
  print("both are equal")
# Out:
# 33
# 45
# larger number is  45

# %%
num = int(input())
if (num%3==0 & num%5==0):
  print("divisible by 3 and 5")
# Out:
# 60
# divisible by 3 and 5

# %%
for(int i=1;i<=5;i++){

}

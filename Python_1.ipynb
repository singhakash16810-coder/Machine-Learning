# %% [markdown]
# <a href="https://colab.research.google.com/github/singhakash16810-coder/Machine-Learning/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LECTURE PLANNER

# %%
# 1. Python Essential -----------> 12
# 2. python for ML & AI  ---> 12
# 3. SQL for ML & AI --> Structered Query Language --> 18
# 4.Numpy --> Python library for Numerical Python --> 6
# 5. EDA using Pandas --> Efficiently deal with Tabular data using Python ----> 12
# 6. Data Visualisation using Python --> Matplotilb,Seabormn:->6
# 7.Prob & Stat; -> 12
# Classical ML --> classification , Regression ->12
# 9. Deep Learning--> Neural Networks.-> 12
# 10. Gen AI & Prompt Engineering --> LLM , Framework for prompt engng -> 16
# 11. RAG, Agents,MCP---> -> 16
# 12. Project & Deployment--> -> 5

# %% [markdown]
# #Importants points to remember

# %% [markdown]
# programming -> giving instruction and interacting with computer

# %% [markdown]
# algorithm --> step by step instruction to solve any problem
#
# **programming** is a way of writing these instruction in a language that the computer understan

# %% [markdown]
# #Python basics

# %%
# programming language ---> C , C++, Pyhton , Java , JavaScript..

# why python --> simple to understand programmer friendly
# 1. Rich set of library AI , ML , Web Dev,Automation...


# Hello world prograam ---> c++,python

# Python:
# print("hello World!")

# "apple is Aditya Jain is eating "

# "Aditya Jain is eating apple"

# what is syntax?
# Grammetical rules for that particular programming language

# Why google collab?
# no installation , free ,Runs in Browser
# used accros industries

# %% [markdown]
# #PYTHON CODE

# %%
print("hello World!")
print("kya baat hai")
# Out:
# hello World!
# kya baat hai

# %%
print("hello world")
# Out:
# hello world

# %%
print("HELLO World")
# Out:
# HELLO World

# %%
print("welcome to python")
# Out:
# welcome to python

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
print("A","B","C")
# Out:
# A B C

# %%
print(100)
# Out:
# 100

# %%
print(3+5)
# Out:
# 8

# %%
print(5-3)
# Out:
# 2

# %%
print(4*2)
# Out:
# 8

# %%
print(4/2)
# Out:
# 2.0

# %%
print(4//3)
# Out:
# 1

# %%
print(6/2)
# Out:
# 3.0

# %%
print(6//2)
# Out:
# 3

# %%
print("3+2")
# Out:
# 3+2

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# QUIZ

# %%
# 1. D correct
# 2. B correct
